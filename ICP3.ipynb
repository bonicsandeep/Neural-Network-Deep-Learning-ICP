# %% [markdown]
# #Neural Networks & Deep Learning - ICP-3
# ##In class programming:
# 1.	Use the use case in the class:
#
#   a.	Add more Dense layers to the existing code and check how the accuracy changes.

# %%
import keras
import pandas
from keras.models import Sequential
from keras.layers import Dense, Activation

# load dataset
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

dataset = pd.read_csv("/content/diabetes.csv", header=None).values

X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 2s 4ms/step - loss: 4.4887 - acc: 0.5903
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 3.3628 - acc: 0.5226
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 2.5091 - acc: 0.5851
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.9206 - acc: 0.6389
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.6084 - acc: 0.6458
# Epoch 6/100
# 18/18 [==============================] - 0s 4ms/step - loss: 1.4005 - acc: 0.6771
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.2775 - acc: 0.6736
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.1910 - acc: 0.6858
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0817 - acc: 0.6719
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0502 - acc: 0.6545
# Epoch 11/100
# ...

# %%
import keras
import pandas
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# load dataset
dataset = pd.read_csv("/content/diabetes.csv", header=None).values
# Train Test split
X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)
# Setting random seed
np.random.seed(155)
# Creating Model and adding layer
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(20, activation='relu'))  # added hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer

# Compile the model
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
# Train the model
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
# model Summery
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 3ms/step - loss: 12.5588 - acc: 0.6597
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 3.6167 - acc: 0.4740
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 2.1768 - acc: 0.4896
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.4815 - acc: 0.5122
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.1676 - acc: 0.5312
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0824 - acc: 0.5677
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9356 - acc: 0.5799
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.8875 - acc: 0.6163
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.8586 - acc: 0.6076
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7920 - acc: 0.6111
# Epoch 11/100
# ...

# %% [markdown]
# **Note**: incresing the hidden layers has increased the accuracy. and decreased the loss. which is good.

# %% [markdown]
# 2.	Change the data source to Breast Cancer dataset * available in the source code folder and make required changes. Report accuracy of the model.

# %%
# loading new data and data preposesing
df = pd.read_csv("/content/breastcancer.csv")
df.drop(['Unnamed: 32','id'], axis=1, inplace=True)
df.replace('M',0.0,inplace=True)
df.replace('B',1.0,inplace=True)
dataset = df.values
# Train Test split
X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,1:], dataset[:,0],
                                                    test_size=0.25, random_state=87)
# Setting random seed
np.random.seed(155)
# Creating model
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=dataset.shape[1]-1, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
# compile the model
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
# Trian the model
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
# Print Model Summery
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 6ms/step - loss: 47.1617 - acc: 0.3803
# Epoch 2/100
# 14/14 [==============================] - 0s 4ms/step - loss: 12.6373 - acc: 0.3991
# Epoch 3/100
# 14/14 [==============================] - 0s 4ms/step - loss: 5.7036 - acc: 0.5423
# Epoch 4/100
# 14/14 [==============================] - 0s 4ms/step - loss: 2.4792 - acc: 0.5986
# Epoch 5/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.8990 - acc: 0.7653
# Epoch 6/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6371 - acc: 0.8357
# Epoch 7/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5340 - acc: 0.8216
# Epoch 8/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5409 - acc: 0.8404
# Epoch 9/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4607 - acc: 0.8685
# Epoch 10/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4265 - acc: 0.8732
# Epoch 11/100
# ...

# %% [markdown]
# **Note**: Accuracy of the model is 92.3%

# %% [markdown]
# 3.	Normalize the data before feeding the data to the model and check how the normalization change your accuracy (code given below).

# %%
from sklearn.preprocessing import StandardScaler

# Load dataset
df = pd.read_csv("breastcancer.csv")
df.drop(['Unnamed: 32', 'id'], axis=1, inplace=True)
df.replace('M', 0.0, inplace=True)
df.replace('B', 1.0, inplace=True)

# Prepare the dataset
dataset = df.values
X = dataset[:, 1:]
Y = dataset[:, 0]

# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=87)

# Standardize the data
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Setting random seed
np.random.seed(155)
# creating model
my_first_nn = Sequential()
my_first_nn.add(Dense(20, input_dim=X_train.shape[1], activation='relu'))  # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid'))  # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, initial_epoch=0)
# printing model Summery
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 5ms/step - loss: 0.6245 - acc: 0.6667
# Epoch 2/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4522 - acc: 0.8662
# Epoch 3/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3466 - acc: 0.9131
# Epoch 4/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2807 - acc: 0.9366
# Epoch 5/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2367 - acc: 0.9484
# Epoch 6/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2052 - acc: 0.9460
# Epoch 7/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1824 - acc: 0.9460
# Epoch 8/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1649 - acc: 0.9484
# Epoch 9/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1504 - acc: 0.9531
# Epoch 10/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1388 - acc: 0.9554
# Epoch 11/100
# ...

# %% [markdown]
# **Note**: normalization has increased the accuracy to 97.2%. which is big boost.

# %% [markdown]
# ##Use Image Classification on the hand written digits data set (mnist)
#
# 1.	Plot the loss and accuracy for both training data and validation data using the history object in the source code.

# %%
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()

print(train_images.shape[1:])
#process the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')
#scale data
train_data /=255.0
test_data /=255.0
#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
# Plot the training and validation loss and accuracy
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# (28, 28)
# 784
# Epoch 1/10
# 235/235 [==============================] - 2s 5ms/step - loss: 0.2867 - accuracy: 0.9121 - val_loss: 0.1338 - val_accuracy: 0.9579
# Epoch 2/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1009 - accuracy: 0.9691 - val_loss: 0.1030 - val_accuracy: 0.9664
# Epoch 3/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0634 - accuracy: 0.9803 - val_loss: 0.0853 - val_accuracy: 0.9740
# Epoch 4/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0433 - accuracy: 0.9866 - val_loss: 0.0814 - val_accuracy: 0.9740
# Epoch 5/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0314 - accuracy: 0.9904 - val_loss: 0.0683 - val_accuracy: 0.9810
# Epoch 6/10
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0228 - accuracy: 0.9926 - val_loss: 0.0965 - val_accuracy: 0.9750
# Epoch 7/10
# ...

# %% [markdown]
# 2.	Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model on that single image.

# %%
# Plot a single image from the test set
plt.imshow(test_images[0], cmap='gray')
plt.title("Ground Truth: {}".format(np.argmax(test_labels_one_hot[0])))
plt.show()

# Predict the digit for the same image
prediction = model.predict(test_data[0].reshape(1, -1))
predicted_digit = np.argmax(prediction)
print("Predicted Digit: ", predicted_digit)
# Out:
# 1/1 [==============================] - 0s 142ms/step
# Predicted Digit:  7

# %% [markdown]
# **Note**: As we can see Prediction value and Groud Truth both are same we can say model performing well.

# %% [markdown]
# 3.	We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the activation to tanh or sigmoid and see what happens.

# %%
# Create a new model with different configurations
new_model = Sequential()
new_model.add(Dense(512, activation='tanh', input_shape=(dimData,)))
new_model.add(Dense(512, activation='tanh'))
new_model.add(Dense(512, activation='tanh'))
new_model.add(Dense(10, activation='softmax'))

new_model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
new_history = new_model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                            validation_data=(test_data, test_labels_one_hot))

# Plot the loss and accuracy for the new model
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(new_history.history['accuracy'])
plt.plot(new_history.history['val_accuracy'])
plt.title('New Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(new_history.history['loss'])
plt.plot(new_history.history['val_loss'])
plt.title('New Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/10
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4039 - accuracy: 0.8762 - val_loss: 0.2039 - val_accuracy: 0.9391
# Epoch 2/10
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1586 - accuracy: 0.9519 - val_loss: 0.1395 - val_accuracy: 0.9563
# Epoch 3/10
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0985 - accuracy: 0.9697 - val_loss: 0.0975 - val_accuracy: 0.9693
# Epoch 4/10
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0688 - accuracy: 0.9785 - val_loss: 0.1001 - val_accuracy: 0.9671
# Epoch 5/10
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0495 - accuracy: 0.9845 - val_loss: 0.0663 - val_accuracy: 0.9787
# Epoch 6/10
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0359 - accuracy: 0.9887 - val_loss: 0.1083 - val_accuracy: 0.9651
# Epoch 7/10
# ...

# %% [markdown]
# **Note**: Changing the hidden layers and activation funcation had no significent difference on this data.

# %%
# Without scaling the images
train_data_no_scale = train_images.reshape(train_images.shape[0], dimData).astype('float')
test_data_no_scale = test_images.reshape(test_images.shape[0], dimData).astype('float')

# Create the model
model_no_scale = Sequential()
model_no_scale.add(Dense(512, activation='relu', input_shape=(dimData,)))
model_no_scale.add(Dense(512, activation='relu'))
model_no_scale.add(Dense(10, activation='softmax'))

model_no_scale.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history_no_scale = model_no_scale.fit(train_data_no_scale, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                                      validation_data=(test_data_no_scale, test_labels_one_hot))

# Plot the loss and accuracy for the non-scaled data model
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_no_scale.history['accuracy'])
plt.plot(history_no_scale.history['val_accuracy'])
plt.title('Model accuracy with scaling')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history_no_scale.history['loss'])
plt.plot(history_no_scale.history['val_loss'])
plt.title('Model loss with scaling')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/10
# 235/235 [==============================] - 2s 5ms/step - loss: 6.3974 - accuracy: 0.8707 - val_loss: 1.0561 - val_accuracy: 0.8747
# Epoch 2/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3822 - accuracy: 0.9448 - val_loss: 0.3227 - val_accuracy: 0.9504
# Epoch 3/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2304 - accuracy: 0.9588 - val_loss: 0.2815 - val_accuracy: 0.9591
# Epoch 4/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1759 - accuracy: 0.9669 - val_loss: 0.2802 - val_accuracy: 0.9559
# Epoch 5/10
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1526 - accuracy: 0.9722 - val_loss: 0.3492 - val_accuracy: 0.9544
# Epoch 6/10
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1503 - accuracy: 0.9755 - val_loss: 0.2835 - val_accuracy: 0.9647
# Epoch 7/10
# ...

# %% [markdown]
# **Note**: As data is scaled we can see there is change in converstion point in the plot. we can see loss has change dreasticaly after first epochs. but there is no much change in model performence.
